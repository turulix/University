# %% [markdown]
# # Abgabe 1
# Hinweise:
# - Bearbeiten Sie alle Aufgaben bis zum **02.05.2024, 20 Uhr**.
# - Bei den Aufgaben 1.2, 2.2 und 4 soll ein (kleines) Gurobi-Programm geschrieben werden. Reichen sie dieses bitte als Jupyter Notebook ein. Die restlichen Abgaben können sie entweder als Markdown (Jupyter), pdf oder auch als Foto einer handgeschriebenen Lösung abgeben.
# - Sie können die Lösung in Gruppen bearbeiten, aber jede/r sollte eine eigene Lösung abgeben.
# - Als Teil der Klausurzulassung müssen sie 50\% der Aufgaben korrekt lösen. Versuchen sie aber, bei *allen* Aufgaben zumindest Lösungsansätze zu entwickeln.
#
# # Aufgabe 1: Lineare Optimierung
# 1. Geben Sie für folgendes lineares Programm die Standardform (in Matrixschreibweise) an
#    \begin{alignat*}{5}
#     \max          & \quad  &   x_1+x_2 &          & & \\[4mm]
#     \text{s.t. } & &  2x_1+x_3 & \geq \phantom{-}  7 && \quad\quad & &  \\[2mm]
#     & &  5x_1 - x_3 & \leq \phantom{-}  5 &&  & &  \\[2mm]
#     & & -3x_1 -3 x_2 & \geq   -3 &&  & &  \\[2mm]
#     & &  x_2, x_3 & \geq \phantom{-}  0 && &&
#     \end{alignat*}
#
# 2. Drei Fabriken beliefern vier Kunden mit Desinfektionsmittel. Die Kapazität der Fabriken, die Bedarfe der Kunden und die Transportkosten pro Tonne (abhängig von Start und Ziel) sind in folgender Tabelle zusammengefasst:
#    |                       | Kunde 1   | Kunde 2   | Kunde 3   | Kunde 4   | **Kapazität [t]**
#    |---                    |---        |---        |---        |---        |---
#    | Fabrik 1              | 132       |           | 97        | 103       | **135**
#    | Fabrik 2              | 85        | 91        |           |           | **56**
#    | Fabrik 3              | 106       | 89        | 100       | 89        | **93**
#    | **Bedarf [t]**        | **62**    | **83**    | **39**    | **91**    |
#
#    Eine leere Zelle bedeutet, dass die Fabrik den entsprechenden Kunden nicht beliefern kann.
#
#    1. Geben Sie ein lineares Programm an, dessen Lösung ein kostenminimaler Transportplan ist. Führen Sie dazu zunächst geeignete Indexmengen ein, die sie dann bei der Formulierung der Variablen, Zielfunktion und Constraints benutzen.
#    2. Implementieren Sie das Problem in Python, lösen Sie es mit Gurobi und geben Sie die Lösung aus.
#
# # Aufgabe 2: Standardprobleme
# 1. Geben Sie das minimale Überdeckungsproblem für die Menge $S=\{1,2,3,4,5\}$ und das Mengensystem
#    $$
#     C=\{\{1,2,3\},\{2,5\},\{1,5\},\{1,4,5\},\{2,3,4\},\{5\}\}
#     $$
#     an.
# 2. Sie besitzen ein 100m langes und 1m breites Stahlblech, von dem mehrere 1m breite Stücke unterschiedlicher Länge abgeschnitten werden sollen. Ihnen liegen insgesamt 7 Aufträge für unterschiedliche Längen vor. Der Erlös, den Sie pro m² Blech erzielen, ist von Auftrag zu Auftrag unterschiedlich. Die Auftragsdaten sind wie folgt:
#    1. Auftrag 1: 33m, 27EUR/m²
#    1. Auftrag 2: 41m, 28EUR/m²
#    1. Auftrag 3: 57m, 22EUR/m²
#    1. Auftrag 4: 19m, 29EUR/m²
#    1. Auftrag 5: 11m, 24EUR/m²
#    1. Auftrag 6: 61m, 25EUR/m²
#    1. Auftrag 7: 19m, 28EUR/m²
#
#    Welche der Aufträge sollten Sie annehmen, um mit dem 100m langen Blech den maximalen Profit zu erzielen? Stellen Sie dazu das LP auf, lösen Sie es mit Gurobi und geben Sie die Lösung an.
#
# # Aufgabe 3: Modellierungstricks
# 1. Geben sie eine Menge von linearen Nebenbedingungen an, die zur Nebenbedingung $|x_1-x_2|\leq 5$ äquivalent sind.
# 2. Formulieren sie folgendes Problem als MILP:
#    \begin{alignat*}{5}
#     \min_{x_1,x_2,x_3}          & \quad  &    \min \{x_1+x_2,\ x_1+3x_3\} &          & & \\[4mm]
#     \text{s.t. } & & -1 \leq x_1,x_2,x_3\leq 1  \\[2mm]
#     \end{alignat*}
#
# # Aufgabe 4: Modellierung
# Eine Marktfrau trug einen Korb mit Eiern zum Markt. Ein Passant stieß versehentlich mit ihr zusammen, woraufhin sie den Korb fallen ließ. Alle Eier waren zerbrochen. Der Passant wollte für den Verlust aufkommen und fragte, wie viele Eier in dem Korb gewesen seien. Die Marktfrau antwortete: "Ich weiß es nicht genau, aber ich erinnere mich noch, dass, wenn ich die Anzahl der Eier durch 2, 3, 4, 5 oder 6 teilte, immer genau ein Ei übrig blieb. Wenn ich aber die Eier in 7er-Gruppen entnahm, so war der Korb am Ende leer."
#
# Welches ist die kleinstmögliche Anzahl von Eiern, die zerbrochen sind? Formulieren sie das Problem als ILP und lösen sie es mit Gurobi.
